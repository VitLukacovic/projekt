# %% [markdown]
# import

# %%
from library import Maze

# %% [markdown]
# ŠABLONY

# %% [markdown]
# empty

# %%
maze_default_empty = Maze()
maze_default_empty.generate_maze(size=15, template="empty", fill_attempts=0)
maze_default_empty.save_to_image("default_empty.png")

# %% [markdown]
# slalom

# %%
maze_default_slalom = Maze()
maze_default_slalom.generate_maze(size=15, template="slalom", fill_attempts=0)
maze_default_slalom.save_to_image("default_slalom.png")

# %% [markdown]
# X

# %%
maze_default_X = Maze()
maze_default_X.generate_maze(size=15, template="X", fill_attempts=0)
maze_default_X.save_to_image("default_X.png")

# %% [markdown]
#  "+"

# %%
maze_default_plus = Maze()
maze_default_plus.generate_maze(size=15, template="+", fill_attempts=0)
maze_default_plus.save_to_image("default_plus.png")

# %% [markdown]
# mrizka

# %%
maze_default_mrizka = Maze()
maze_default_mrizka.generate_maze(size=15, template="mrizka", fill_attempts=0)
maze_default_mrizka.save_to_image("default_mrizka.png")
