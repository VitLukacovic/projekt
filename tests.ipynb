# %% [markdown]
# nahrajeme knihovnu

# %%
from knihovna import Maze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from knihovna import Maze
#
# File d:\skola\vyska\VAM\VVP\projekt\projekt\knihovna\__init__.py:1
# ----> 1 from .bludiste import Maze
#       2 from .vyjimky import NoPathError, MazeNotInitializedError
#       4 __all__ = ["Maze", "NoPathError", "MazeNotInitializedError"]
#
# File d:\skola\vyska\VAM\VVP\projekt\projekt\knihovna\bludiste.py:9
#       6 from PIL import Image
#       7 from typing import List, Tuple, Optional, Dict
# ----> 9 from .vyjimky import NoPathError, MazeNotInitializedError
#      11 # Konstanty pro barvy (RGB) - zamezení tzv. hardcoded konstant v logice
#      12 COLOR_WALL: Tuple[int, int, int] = (0, 0, 0)
#
# ModuleNotFoundError: No module named 'knihovna.vyjimky'

# %% [markdown]
# Načtení a řešení existujícího bludiště z CSV

# %%
print("1. TEST NAČTENÍ Z CSV A HLEDÁNÍ CESTY")
maze_from_csv = Maze.from_csv("data/maze_5.csv")
cesta = maze_from_csv.find_shortest_path()

print(f"Cesta nalezena! Počet kroků: {len(cesta)}")
maze_from_csv.save_to_image("maze_5_vyresene.png")
print("Obrázek uložen jako solved_maze_csv.png")

# %% [markdown]
# Generování z prázdné šablony

# %%
print("\n2. TEST GENEROVÁNÍ (ŠABLONA: EMPTY)")
maze_empty = Maze()
maze_empty.generate_maze(size=15, template="empty", fill_attempts=40)
maze_empty.save_to_image("generated_empty.png")
print("Obrázek uložen jako generated_empty.png")

# %% [markdown]
# Generování ze slalomové šablony

# %%
print("\n3. TEST GENEROVÁNÍ (ŠABLONA: SLALOM)")
maze_slalom = Maze()
maze_slalom.generate_maze(size=15, template="slalom", fill_attempts=30)
maze_slalom.save_to_image("generated_slalom.png")
print("Obrázek uložen jako generated_slalom.png")
